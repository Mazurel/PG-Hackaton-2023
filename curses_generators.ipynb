# %%
import pandas as pd
import re
import numpy as np
import itertools

# %%
dictionary = {'o':'0','O':'0','b':'8','B':'8','s':'5','S':'5','e':'3','E':'3','G':'6','g':'9','z':'2','Z':'2','a':'@','A':'4','T':'7','u':'v','w':'vv','l':'I','I':'l'}

# %%
list_keys = list(dictionary.keys())
list_values = list(dictionary.values())
# Out:
# 19

# %%
def generator(list): # generator of a swears (multiple letters)
# to use it you have to decide how many letters you want change in a word, for example if you want to change two letters, 
#you need to writedown two replaces(element) with lists of keys and lists of values    
    full_list = []
    for elem in range(len(list_keys)):
        list_out = [element.replace(list_keys[elem],list_values[elem]) for element in list]
        full_list +=list_out
    df = pd.DataFrame({'col1':set(full_list)})
    print(df)
generator(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11052\3921979627.py in <module>
#       8     df = pd.DataFrame({'col1':set(full_list)})
#       9     print(df)
# ---> 10 generator(data)
#
# ~\AppData\Local\Temp\ipykernel_11052\3921979627.py in generator(list)
#       6         list_out = [element.replace(list_keys[elem],list_values[elem]) for element in list]
#       7         full_list +=list_out
# ----> 8     df = pd.DataFrame({'col1':set(full_list)})
#       9     print(df)
#      10 generator(data)
#
# c:\users\micpo\perl\thonny\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
tablica_testowa = ['cos tam', 'hotorke','sdaonewf']
def generator(list): # Test  
    full_list = []
    for elem in range(len(list_keys)):
        list_out = [element.replace(list_keys[0],list_values[0]).replace(list_keys[1],list_values[1]).replace(list_keys[2],list_values[2]).replace(list_keys[3],list_values[3])
                    .replace(list_keys[4],list_values[4]).replace(list_keys[5],list_values[5]).replace(list_keys[6],list_values[6]).replace(list_keys[7],list_values[7])
                    .replace(list_keys[8],list_values[8]).replace(list_keys[9],list_values[9]).replace(list_keys[10],list_values[10]).replace(list_keys[11],list_values[11])
                    .replace(list_keys[12],list_values[12]).replace(list_keys[13],list_values[13]).replace(list_keys[14],list_values[14]).replace(list_keys[15],list_values[15])for element in list]
        full_list +=list_out
    print(full_list)
generator(tablica_testowa)
# Out:
# ['c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf', 'c05 t@m', 'h0t0rk3', '5d@0n3wf']

# %%
# combination of 2 letters 
lista = []
lista_values = []


for k in itertools.combinations(dictionary, 2): # this line of code creates combination of 2 keys which are stored in list_keys_2 and list_keys_22 
    lista.append(k)
list_keys_2 = []
list_keys_22 = []

for i in range(len(lista)) :     
    list_keys_2.append(lista[i][0])
    list_keys_22.append(lista[i][1])
    

df_2 = pd.DataFrame(list_keys_2)
df_2.columns = ['key']
df_2_C = df_2['key'].map(dictionary)
df_2_C = pd.DataFrame(df_2_C)
df_2_C.columns = ['value']
df_final = pd.concat([df_2,df_2_C],axis=1)

list2 =df_final.values.tolist()
###################################################
lista_key2 = df_final['key'].values.tolist() # this variable we put in replace
lista_value2 = df_final['value'].values.tolist() # this variable we put in replace
###################################################

df_2 = pd.DataFrame(list_keys_22)
df_2.columns = ['key']
df_2_C = df_2['key'].map(dictionary)
df_2_C = pd.DataFrame(df_2_C)
df_2_C.columns = ['value']
df_final22 = pd.concat([df_2,df_2_C],axis=1)

list22 =df_final22.values.tolist()
###################################################
lista_key22 = df_final22['key'].values.tolist() # this variable we put in replace
lista_value22 = df_final22['value'].values.tolist() # this variable we put in replace
###################################################

# %%
# combination of 3 letters 
lista = []

for k in itertools.combinations(dictionary, 3):
    lista.append(k)
list_keys_3 = []
list_keys_33 = []
list_keys_333 = []

for i in range(len(lista)):     
    list_keys_3.append(lista[i][0])
    list_keys_33.append(lista[i][1])
    list_keys_333.append(lista[i][2])

df_3 = pd.DataFrame(list_keys_3)
df_3.columns = ['key']
df_3_C = df_3['key'].map(dictionary)
df_3_C = pd.DataFrame(df_3_C)
df_3_C.columns = ['value']
df_final3 = pd.concat([df_3,df_3_C],axis=1)

list3 =df_final3.values.tolist()
###################################################
lista_key3 = df_final3['key'].values.tolist()# this variable we put in replace
lista_value3 = df_final3['value'].values.tolist()# this variable we put in replace
###################################################

df_33 = pd.DataFrame(list_keys_33)
df_33.columns = ['key']
df_33_C = df_33['key'].map(dictionary)
df_33_C = pd.DataFrame(df_33_C)

df_33_C.columns = ['value']
df_final33 = pd.concat([df_33,df_33_C],axis=1)

list33 =df_final33.values.tolist()
###################################################
lista_key33 = df_final33['key'].values.tolist()# this variable we put in replace
lista_value33 = df_final33['value'].values.tolist()# this variable we put in replace
###################################################
df_333 = pd.DataFrame(list_keys_333)
df_333.columns = ['key']
df_333_C = df_333['key'].map(dictionary)
df_333_C = pd.DataFrame(df_333_C)
df_333_C.columns = ['value']
df_final333 = pd.concat([df_333,df_333_C],axis=1)

list333 =df_final333.values.tolist()
#####################################################
lista_key333 = df_final333['key'].values.tolist()# this variable we put in replace
lista_value333 = df_final333['value'].values.tolist()# this variable we put in replace
#####################################################

# %%
# combination of 4 letters 
lista = []

for k in itertools.combinations(dictionary, 4):
    lista.append(k)
list_keys_4 = []
list_keys_44 = []
list_keys_444 = []
list_keys_4444 = []
for i in range(len(lista)):     
    list_keys_4.append(lista[i][0])
    list_keys_44.append(lista[i][1])
    list_keys_444.append(lista[i][2])
    list_keys_4444.append(lista[i][3])
df_4 = pd.DataFrame(list_keys_4)
df_4.columns = ['key']
df_4_C = df_4['key'].map(dictionary)
df_4_C = pd.DataFrame(df_4_C)
df_4_C.columns = ['value']
df_final4 = pd.concat([df_4,df_4_C],axis=1)
list4 =df_final4.values.tolist()

###################################################
lista_key4 = df_final4['key'].values.tolist()# this variable we put in replace
lista_value4 = df_final4['value'].values.tolist()# this variable we put in replace
###################################################

df_44 = pd.DataFrame(list_keys_44)
df_44.columns = ['key']
df_44_C = df_44['key'].map(dictionary)
df_44_C = pd.DataFrame(df_44_C)

df_44_C.columns = ['value']
df_final44 = pd.concat([df_44,df_44_C],axis=1)
list44 =df_final44.values.tolist()

lista_key44 = df_final44['key'].values.tolist()# this variable we put in replace
lista_value44 = df_final44['value'].values.tolist()# this variable we put in replace

df_444 = pd.DataFrame(list_keys_444)
df_444.columns = ['key']
df_444_C = df_444['key'].map(dictionary)
df_444_C = pd.DataFrame(df_444_C)
df_444_C.columns = ['value']
df_final444 = pd.concat([df_444,df_444_C],axis=1)
list444 =df_final444.values.tolist()

lista_key444 = df_final444['key'].values.tolist()# this variable we put in replace
lista_value444 = df_final444['value'].values.tolist()# this variable we put in replace

df_4444 = pd.DataFrame(list_keys_4444)
df_4444.columns = ['key']
df_4444_C = df_4444['key'].map(dictionary)
df_4444_C = pd.DataFrame(df_4444_C)
df_4444_C.columns = ['value']
df_final4444 = pd.concat([df_4444,df_4444_C],axis=1)
list4444 =df_final4444.values.tolist()

lista_key4444 = df_final4444['key'].values.tolist()# this variable we put in replace
lista_value4444 = df_final4444['value'].values.tolist()# this variable we put in replace

# %%
my_file = open("duzo_wulgaryzmow.txt", "r")
  
# reading the file
data = my_file.read()
  

data = data.split("\n")
data
# Out:
# ['gĂłwno',
#  'afa',
#  'bladĹş',
#  'bloĹ‚dĹĽob',
#  'brandzlowaÄ‡',
#  'brandzlowanie',
#  'burdelchata',
#  'burdelĂłwa',
#  'bzykaÄ‡',
#  'bzykanko',
#  'ChWDP',
#  'CJK',
#  'certoliÄ‡',
#  'chÄ™doĹĽenie',
#  'cholernie',
#  'chuj',
#  'chujek',
#  'chujnia',
#  'chujostwo',
#  'chujowizna',
#  'chujowo',
#  'chujowoĹ›Ä‡',
#  'chujowy',
#  'chujoza',
#  'ciÄ…gnÄ…Ä‡',
#  'cichodajka',
#  'ciota',
#  'cipa',
#  'cipowanie',
#  'cipowy',
#  'ciul',
#  'ciulaÄ‡',
#  'ciulnÄ…Ä‡',
#  'cwel',
#  'cweliÄ‡',
#  'cwelowanie',
#  'cyc',
#  'cycatka',
#  'cyckoman',
#  'dmuchaÄ‡',
#  'dmuchanie',
#  'dojebaÄ‡',
#  'dopierdalaÄ‡',
#  'dopierdalanie',
#  'dupa',
#  'dupczenie',
#  'dupczyÄ‡',
#  'dupiasty',
#  'dupiaty',
#  'dupnÄ…Ä‡',
#  'dupny',
#  'dupogodzina',
#  'dupojebak',
#  'dupojebstwo',
#  'dupoliz',
#  'dymaÄ‡',
#  'dymanko',
#  'dziwka',
#  'frajer',
#  'gnĂłj',
#  'gĂłwniak',
#  'gĂłwnianoĹ›Ä‡',
#  'gĂłwniany',
#  'gĂłwniara',
#  'gĂłwniarz',
#  'gĂłwnix',
#  'gĂłwno',
# ...

# %%
dictionary = {'o':'0','O':'0','b':'8','B':'8','s':'5','S':'5','e':'3','E':'3','G':'6','g':'9','z':'2','Z':'2','a':'@','A':'4','T':'7','u':'v','w':'vv','l':'I','I':'l'}
def generator_2(list): # g3ner@tor of w0rd5 (single letters different positions) 
    output_list = []
    for key,value in dictionary.items():
        for j in range(1,5):
             for i in range(len(list)):
                    output = re.sub(key, value, list[i], j)
                    output_list.append(output)
        print(output_list)
    for key,value in dictionary.items(): 
        for j in range(1,5):
             for i in range(len(list)):
                regex = key + "(?!.*" + key + ")"
                output2 = re.sub(regex, value, list[i],j)
                output_list.append(output2)
                df = pd.DataFrame({'col':output_list})
                np.savetxt(r'bluzgii.txt', df.values,fmt='%s')
generator_2(data)
